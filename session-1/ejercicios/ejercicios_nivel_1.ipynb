# %% [markdown]
# ## Ejercicio 1: Variables y Print
#
# Crea tres variables:
# - `mi_nombre` con tu nombre
# - `mi_edad` con tu edad
# - `mi_hobby` con tu pasatiempo favorito
#
# Luego imprime un mensaje que diga: "Me llamo [nombre], tengo [edad] años y me gusta [hobby]"

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 2: Operaciones Matemáticas
#
# Crea dos variables numéricas `a = 15` y `b = 4`, luego calcula e imprime:
# - La suma
# - La resta
# - La multiplicación
# - La división
# - El módulo (residuo)

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 3: Tipos de Datos
#
# Crea las siguientes variables y usa `type()` para mostrar su tipo:
# - Un número entero
# - Un número decimal
# - Un texto
# - Un booleano (True o False)

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 4: Conversión de Tipos
#
# Pide al usuario dos números (usa `input()`), conviértelos a enteros y muestra su suma.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 5: Condicional Simple
#
# Pide la edad del usuario. Si es mayor o igual a 18, imprime "Eres mayor de edad", si no, imprime "Eres menor de edad".

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 6: Par o Impar
#
# Pide un número al usuario y determina si es par o impar.
#
# **Pista:** Un número es par si `numero % 2 == 0`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 7: Calificaciones
#
# Pide una calificación (0-100) y muestra:
# - "Excelente" si es >= 90
# - "Muy bien" si es >= 80
# - "Bien" si es >= 70
# - "Suficiente" si es >= 60
# - "Reprobado" si es < 60

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 8: Ciclo For Básico
#
# Usa un ciclo `for` para imprimir los números del 1 al 10.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 9: Suma de Números
#
# Calcula la suma de los números del 1 al 100 usando un ciclo.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 10: Tabla de Multiplicar
#
# Pide un número al usuario e imprime su tabla de multiplicar del 1 al 10.
#
# Ejemplo: Si el usuario ingresa 5, debes mostrar:
# ```
# 5 x 1 = 5
# 5 x 2 = 10
# ...
# 5 x 10 = 50
# ```

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 11: Contar Pares
#
# Cuenta cuántos números pares hay entre 1 y 50.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 12: Función Simple
#
# Crea una función llamada `saludar` que reciba un nombre y retorne un saludo personalizado.
#
# Ejemplo: `saludar("Ana")` debe retornar `"Hola, Ana!"`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 13: Función de Área
#
# Crea una función `area_rectangulo(base, altura)` que calcule y retorne el área de un rectángulo.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 14: Función Mayor de Dos
#
# Crea una función `mayor(a, b)` que retorne el mayor de dos números.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 15: Iterar sobre Lista
#
# Dada la lista `frutas = ["manzana", "banana", "naranja", "uva"]`, imprime cada fruta precedida por su número de posición (empezando en 1).
#
# Salida esperada:
# ```
# 1. manzana
# 2. banana
# 3. naranja
# 4. uva
# ```

# %%
# Tu código aquí

# %% [markdown]
# ## 🎉 ¡Felicidades!
#
# Has completado los ejercicios de Nivel 1. Si pudiste resolver la mayoría:
#
# ✅ Entiendes los conceptos básicos de Python
# ✅ Puedes usar variables, condicionales y ciclos
# ✅ Sabes crear funciones simples
#
# **Próximo paso:** Intenta los ejercicios de Nivel 2 para un mayor desafío.
