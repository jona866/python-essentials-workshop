# %% [markdown]
# ## Ejercicio 1: Validador de Contraseña
#
# Crea una función `es_password_valida(password)` que retorne True si la contraseña cumple estas reglas:
# - Tiene al menos 8 caracteres
# - Contiene al menos un número
#
# **Pista:** Usa `len()` y el método `.isdigit()` para verificar si un carácter es un número

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 2: Números Primos
#
# Crea una función `es_primo(numero)` que determine si un número es primo.
#
# Un número primo solo es divisible por 1 y por sí mismo.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 3: FizzBuzz
#
# Imprime los números del 1 al 30, pero:
# - Si el número es divisible por 3, imprime "Fizz"
# - Si es divisible por 5, imprime "Buzz"
# - Si es divisible por ambos, imprime "FizzBuzz"
# - Si no, imprime el número

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 4: Invertir una Cadena
#
# Crea una función `invertir_texto(texto)` que retorne el texto invertido.
#
# Ejemplo: `invertir_texto("hola")` debe retornar `"aloh"`

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 5: Contar Vocales
#
# Crea una función `contar_vocales(texto)` que cuente cuántas vocales (a, e, i, o, u) hay en un texto.
#
# Debe funcionar con mayúsculas y minúsculas.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 6: Palíndromo
#
# Crea una función `es_palindromo(texto)` que determine si una palabra se lee igual al derecho y al revés.
#
# Ejemplos: "ana", "radar", "reconocer"

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 7: Calculadora de Propinas
#
# Crea una función `calcular_propina(total, porcentaje=15, personas=1)` que:
# - Calcule la propina basada en el porcentaje
# - Divida el total (incluyendo propina) entre el número de personas
# - Retorne el total con propina y cuánto paga cada persona
#
# El porcentaje por defecto es 15% y el número de personas por defecto es 1.

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 8: Adivina el Número
#
# Crea un juego donde:
# 1. El programa "piensa" un número entre 1 y 100 (usa `numero_secreto = 42` por ahora)
# 2. El usuario tiene 7 intentos para adivinarlo
# 3. Después de cada intento, el programa dice si el número es mayor o menor
# 4. Si adivina, muestra un mensaje de éxito
# 5. Si se agotan los intentos, muestra el número secreto

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 9: Analizador de Lista
#
# Crea una función `analizar_lista(numeros)` que reciba una lista de números y retorne:
# - La suma total
# - El promedio
# - El número mayor
# - El número menor
# - Cuántos números son positivos
# - Cuántos son negativos

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio 10: Patrón de Pirámide
#
# Crea una función `piramide(altura)` que imprima una pirámide de asteriscos.
#
# Ejemplo para `piramide(5)`:
# ```
#     *
#    ***
#   *****
#  *******
# *********
# ```

# %%
# Tu código aquí

# %% [markdown]
# ## 🎉 ¡Excelente Trabajo!
#
# Si completaste estos ejercicios:
#
# ✅ Tienes un dominio sólido de Python básico
# ✅ Puedes combinar diferentes conceptos
# ✅ Estás listo para proyectos más complejos
#
# **Próximo paso:** Desarrolla el mini proyecto integrador.
